# %% [markdown]
# * [57 of 415]를 기록한 커널입니다.
# * Kaggle 대회가 처음이라 횡설수설 코딩을 해 읽기 불편하신 점 죄송합니다.
# * 최고점수를 찍었을 때 코드를 따로 저장해놓지 않고 계속 바꾸다 보니 점수가 재현이되지 않았습니다..
# * 일주일간 연구 끝에 private score는 더 좋게 재현했으나 public score는 재현하지 못했습니다..ㅠ
# * 상품은 받지 못하더라도 원래 목적인 kernel을 공유하는 것도 좋은 경험이 될 듯해 이렇게 올리게 되었습니다!
# * **정말 많은 공부가 되었습니다. 감사합니다!!**
# # 2019 2nd ML month with KaKR
# ## 목차
# - **데이터 탐색**
#     - 문제 정의
#     - 변수 설명
#     - 시각화
#     - 이상치 및 결측치 확인
#     - 유니크 갯수
# - **데이터 전처리**
#     - 이상치 및 결측치 처리
#     - 정규화
# - **변수 생성**
# - 모델링
#     - GBM
#     - RandomForest
#     - SVR
#     - ExtraRandomizedTree

# %% [markdown]
# #### 전체적인 데이터 탐색과 Feature engineering 코드는 [Hyun woo kim](https://www.kaggle.com/chocozzz/house-price-prediction-eda-updated-2019-03-12) 님의 커널을 참고했습니다.
# ### 1. 데이터 탐색
# #### 1.1 문제 정의

# %%
# Loding packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import gc

# %%
# !kaggle competitions download -c 2019-2nd-ml-month-with-kakr

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (15035, 21)
# (6468, 20)

# %%
df_train.head(50)
# Out:
#     id             date      price  bedrooms  bathrooms  sqft_living  \
# 0    0  20141013T000000   221900.0         3       1.00         1180
# 1    1  20150225T000000   180000.0         2       1.00          770
# 2    2  20150218T000000   510000.0         3       2.00         1680
# 3    3  20140627T000000   257500.0         3       2.25         1715
# 4    4  20150115T000000   291850.0         3       1.50         1060
# 5    5  20150403T000000   662500.0         3       2.50         3560
# 6    6  20140527T000000   468000.0         2       1.00         1160
# 7    7  20140528T000000   310000.0         3       1.00         1430
# 8    8  20141007T000000   400000.0         3       1.75         1370
# 9    9  20150312T000000   530000.0         5       2.00         1810
# 10  10  20150124T000000   650000.0         4       3.00         2950
# 11  11  20140731T000000   395000.0         3       2.00         1890
# 12  12  20140529T000000   485000.0         4       1.00         1600
# 13  13  20141205T000000   189000.0         2       1.00         1200
# 14  14  20150424T000000   230000.0         3       1.00         1250
# 15  15  20140514T000000   385000.0         4       1.75         1620
# 16  16  20140826T000000  2000000.0         3       2.75         3050
# 17  17  20140516T000000   252700.0         2       1.50         1070
# 18  18  20141120T000000   329000.0         3       2.25         2450
# 19  19  20141103T000000   233000.0         3       2.00         1710
# 20  20  20140626T000000   937000.0         3       1.75         2450
# 21  21  20141201T000000   667000.0         3       1.00         1400
# 22  22  20141110T000000   580500.0         3       2.50         2320
# 23  23  20140624T000000   687500.0         4       1.75         2330
# 24  24  20141110T000000   535000.0         3       1.00         1090
# 25  25  20141203T000000   322500.0         4       2.75         2060
# 3            2238        6819
# 4            1650        9711
# 5            2210        8925
# 6            1330        6000
# 7            1780       12697
# 8            1370       10208
# 9            1360        4850
# 10           2140        4000
# 11           1890       14018
# 12           1610        4300
# 13           1060        5095
# 14           1280        8850
# 15           1400        4980
# 16           4110       20336
# 17           1220        8386
# 18           2200        6865
# 19           1030        4705
# 20           1760        3573
# 21           1860        3861
# 22           2580        3980
# 23           1460        5000
# 24           1570        5080
# 25           2020        8720
# 26           1590        3264
# 27           1730        4700
# 28           1290        7800
# 29           2620       11884
# 30           2410       30617
# 31           3625        5639
# 32           1580        2640
# 33           1228        8840
# 34           2680       13685
# 35           1410        4080
# 36           1950        5000
# 37           2250        4500
# 38           2690        4750
# 39           2960       11044
# 40           2570       18900
# 41           1290        8750
# 42           1580        3090
# 43           1440        4080
# 44           2750       11049
# 45           2221        4557
# 46           1010       12635
# 47           3530       38917
# 48           1640        4745
# 49           1510        7807
#
# [50 rows x 21 columns]

# %% [markdown]
# 훈련데이터와 시험데이터의 크기는 각각 15035, 6468으로 적은편이고, 비율이 5:2로 심하게 불균등하지는 않습니다. 변수의 갯수가 20개로 적은 편이어서 좋은 피쳐를 만들어내는 것이 모델 성능에 관건으로 생각됩니다.

# %% [markdown]
# #### 1.2 변수 설명
# * ID : 집을 구분하는 번호
# * date : 집을 구매한 날짜
# * price : 집의 가격(Target variable)
# * bedrooms : 침실의 수
# * bathrooms : 화장실의 수
# * sqft_living : 주거 공간의 평방 피트(면적)
# * sqft_lot : 부지의 평방 피트(면적)
# * floors : 집의 층 수
# * waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# * view : Has been viewed
# * condition : 집의 전반적인 상태
# * grade : King County grading 시스템 기준으로 매긴 집의 등급
# * sqft_above : 지하실을 제외한 평방 피트(면적)
# * sqft_basement : 지하실의 평방 피트(면적)
# * yr_built : 지어진 년도
# * yr_renovated : 집을 재건축한 년도
# * zipcode : 우편번호
# * lat : 위도
# * long : 경도
# * sqft_living15 : 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
# * sqft_lot15 : 2015년 기준 주차 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음

# %%
df_train.head(20)
# Out:
#     id             date      price  bedrooms  bathrooms  sqft_living  \
# 0    0  20141013T000000   221900.0         3       1.00         1180
# 1    1  20150225T000000   180000.0         2       1.00          770
# 2    2  20150218T000000   510000.0         3       2.00         1680
# 3    3  20140627T000000   257500.0         3       2.25         1715
# 4    4  20150115T000000   291850.0         3       1.50         1060
# 5    5  20150403T000000   662500.0         3       2.50         3560
# 6    6  20140527T000000   468000.0         2       1.00         1160
# 7    7  20140528T000000   310000.0         3       1.00         1430
# 8    8  20141007T000000   400000.0         3       1.75         1370
# 9    9  20150312T000000   530000.0         5       2.00         1810
# 10  10  20150124T000000   650000.0         4       3.00         2950
# 11  11  20140731T000000   395000.0         3       2.00         1890
# 12  12  20140529T000000   485000.0         4       1.00         1600
# 13  13  20141205T000000   189000.0         2       1.00         1200
# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 21 columns):
# id               15035 non-null int64
# date             15035 non-null object
# price            15035 non-null float64
# bedrooms         15035 non-null int64
# bathrooms        15035 non-null float64
# sqft_living      15035 non-null int64
# sqft_lot         15035 non-null int64
# floors           15035 non-null float64
# waterfront       15035 non-null int64
# view             15035 non-null int64
# condition        15035 non-null int64
# grade            15035 non-null int64
# sqft_above       15035 non-null int64
# sqft_basement    15035 non-null int64
# yr_built         15035 non-null int64
# yr_renovated     15035 non-null int64
# zipcode          15035 non-null int64
# lat              15035 non-null float64
# long             15035 non-null float64
# sqft_living15    15035 non-null int64
# sqft_lot15       15035 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 2.4+ MB

# %% [markdown]
# #### 1.3 변수 시각화(목적 변수)

# %%
# describe statistics summery
df_train['price'].describe()
# Out:
# count    1.503500e+04
# mean     5.406827e+05
# std      3.715247e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# * 목적 변수의 경우 최솟값(min)과 최댓값(max)의 차이가 크고, 표준 편차(std)가 굉장히 큰 편입니다.

# %%
# histogram
plt.figure(figsize=(8,6))
sns.distplot(a=df_train['price'])

# %% [markdown]
# * 가격이 낮은 쪽에 굉장히 치우친 것을 확인이 가능합니다.

# %%
# skewness and krutosis
print('Skewness:', df_train['price'].skew())
print('Kurtosis:', df_train['price'].kurt())
# Out:
# Skewness: 4.290252396939529
# Kurtosis: 40.15491919350329

# %% [markdown]
# * 왜도(skewness) : 데이터 분포가 얼마나 치우쳤는지 보여주는 척도로서, 왼쪽으로 꼬리가 길수록 음수 방향으로 값이 커지고, 오른쪽으로 꼬리가 길수록 양수 방향으로 값이 커진다.
# * 첨도(kurtosis) : 데이터 분포가 분포 가운데에 얼마나 몰려있는지 보여주는 척도로서, 첨도 값(K)이 3에 가까울 경우 그래프는 정규분포에 가깝고, (K<3)이면 정규분포보다 더 평탄하다고 판단할 수 있으며, (K>3)인 경우 정규분포보다 더 뾰족한 분포로 간주 할 수 있다.
# <br><br>
# 위의 목적 변수의 경우 왜도도 정규분포를 따르지 않고 분산 또한 매우 큰것을 확인할 수 있습니다. 회귀 모델 사용을 위해 정규화(Normalize)를 통해 price의 분포가 정규분포에 가깝도록 가공해 주겠습니다.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(10,8)
stats.probplot(x=df_train['price'], plot=axes[0])
stats.probplot(x=np.log1p(df_train['price']), plot=axes[1])
plt.show()

# %% [markdown]
# log를 취해주면 기존보다 더 정규성을 가지는 것을 확인할 수 있습니다.

# %%
df_train['price'] = np.log1p(df_train['price'])
# histogram
plt.figure(figsize=(8,6))
sns.distplot(a=df_train['price'])

# %%
# skewness and krutosis
print('Skewness:', df_train['price'].skew())
print('Kurtosis:', df_train['price'].kurt())
# Out:
# Skewness: 0.4330991387067915
# Kurtosis: 0.7316049825519855

# %% [markdown]
# * 정규분포에 가까워 졌다.

# %%
df_train['price'].describe()
# Out:
# count    15035.000000
# mean        13.048122
# std          0.527471
# min         11.264477
# 25%         12.682310
# 50%         13.017005
# 75%         13.377007
# max         15.856731
# Name: price, dtype: float64

# %% [markdown]
# 편차가 눈에띄게 줄고 최소값과 최대값의 차이도 적은 것을 확인할 수 있다.

# %% [markdown]
# #### 1.3 변수 시각화(반응변수)
# * 피어슨 상관관계 : 연속형 변수에 사용
# * 스피어만 순위 상관관계 : 범주형 변수도 포함되었을 경우에 사용
# <br><br>
# 아래는 목적변수인 가격과 가장 상관관계가 높은 순서대로 스피어만 순위 상관관계를 본 히트맵이다. 편의를 위해 상관도가 높은 상위 15개의 값만 보도록 하겠습니다.

# %%
# saleprice correlation matrix
k = 10 # number of variables for heatmap
corrmat = abs(df_train.corr(method='spearman')) # correlation 전체 변수에 대해서 계산
cols = corrmat.nlargest(k, 'price').index # nlargest : return this many descending sorted values
# cm = np.corrcoef(df_train[cols].values.T) # correlation 특정 칼럼에 대해서

# spearman coeffient matrix
cor = np.array(stats.spearmanr(df_train[cols].values))[0]
print(list(cols))

fig, ax = plt.subplots(figsize=(18,8))
sns.heatmap(data=cor, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8}, yticklabels=cols.values, xticklabels=cols.values, ax=ax)
# Out:
# ['price', 'grade', 'sqft_living', 'sqft_living15', 'sqft_above', 'bathrooms', 'lat', 'bedrooms', 'floors', 'view']

# %% [markdown]
# 목적변수와 상관도가 높은 변수는 집의 등급 - 주거공간의 크기 - 전체 크기순이고, 위도를 뜻하는 lat라는 값도 들어있습니다. 양의 상관관계인것을 보니 위도가 증가할수록 가격의 값이 증가한다는 뜻인데, 왜 이렇것인지, 어떻게 활용할 수 있을지는 탐구가 필요할 듯 합니다.
# * 집의 평수가 넓을수록 등급도 함께 높아지는 경향이 있다.
# * 그리고 이 등급은 가격에 큰 영향을 미친다.

# %%
# np.corrcoef(df_train[cols].values).shape

# %%
data = pd.concat([df_train['price'], df_train['grade']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=data, x='grade', y='price', ax=ax)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,8))
ax[0].set(title='Train set')
sns.countplot(x='grade', data=df_train, ax=ax[0], palette=sns.color_palette('pastel'))

ax[1].set(title='Test set')
sns.countplot(x='grade', data=df_test, ax=ax[1], palette=sns.color_palette('pastel'))

# %% [markdown]
# 집의 등급이 높으면 가격이 높아지는 것은 위의 히트맵에서도 봤듯이 당연한 결과입니다. 그리고 전반적으로 상승곡선 형태도 보이고 있습니다. 하지만
# * **등급 6,7,8,9 에서 이상치(outlier)가 많은 이유**
# * **등급 8과 11에서 차이가 큰 이상치가 나타나는 이유**
# <br>
# 위의 두가지는 좀 더 살펴볼 여지가 있어보입니다.

# %%
data = pd.concat([df_train['sqft_living'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_living', y='price', data=data, ax=ax)

# %% [markdown]
# 전반적으로 선형성을 보이지만 선형성을 보이지만 가격 14~15 사이에 sqft_living이 14000이나 되는 값은 꽤나 이상한 값(이상치)으로 보입니다. 제거할지 말지는 저 값을 확인해보고 결정해 보도록 하겠습니다.

# %%
data = pd.concat([df_train['sqft_living15'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_living15', y='price', data=data, ax=ax)

# %%
sns.distplot(a=df_train['sqft_living15'])

# %% [markdown]
# sqft_living15의 경우 15년도 기준이다보니 가격의 분산이 비교적 큽니다. 아무래도 재건축으로 인한 영향일것으로 생각되어지고 sqft_living15 그 자체를 사용하기보다는 적절한 Feature Engineering이 필요해 보입니다.

# %%
data = pd.concat([df_train['sqft_above'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_above', y='price', data=data)

# %%
data = pd.concat([df_train['bathrooms'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(15,8))
sns.boxplot(x='bathrooms', y='price', data=data, palette=sns.color_palette('pastel'))

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].set(title='Train set')
sns.countplot(x='bathrooms', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='bathrooms', data=df_test, ax=ax[1])

# %% [markdown]
# bathrooms 같은 경우 소수점이 있어 헷갈릴 수도 있스빈다. 각각의 값이 의미하는 것은 아래와 같고, 위의 값만을 가지고 각각의 값이 몇개 있는지는 구분하기 힘들어 보입니다.
# * 0.5 : 세면대, 화장실
# * 0.75 : 세면대, 화장실, 샤워실
# * 1 : 세면대, 화장실, 샤워실, 욕조

# %%
data = pd.concat([df_train['bedrooms'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(12,8))
sns.boxplot(x='bedrooms', y='price', data=data)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,8))
ax[0].set(title='Train set')
sns.countplot(x='bedrooms', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='bedrooms', data=df_test, ax=ax[1])

# %% [markdown]
# 독특하게 방 수가 30이 넘는 값들이 있고, price는 비교적 낮은 것 또한 볼 수 있습니다. 이러한 값들은 특정한 이유가 있어서 이렇게 된 것으로 볼 수 있습니다.(ex)숙박시설, 외딴 지역 등).

# %%
data = pd.concat([df_train['floors'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(10,8))
sns.boxplot(x='floors', y='price', data=data, palette=sns.color_palette('pastel'))

# %%
data = pd.concat([df_train['view'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(12,8))
sns.boxplot(x='view', y='price', data=data, palette=sns.color_palette('pastel'))

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(12,8))
ax[0].set(title='Train set')
sns.countplot(x='view', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='view', data=df_test, ax=ax[1])

# %% [markdown]
# * 많이 보여준 방일수록 가격이 오르는것을 확인이 가능
# * 분포가 대부분이 0쪽으로 치우쳐 있습니다.

# %%
data = pd.concat([df_train['waterfront'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(12,8))
sns.boxplot(x='waterfront', y='price', data=data)

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(12,8))
ax[0].set(title='Train set')
sns.countplot(x='waterfront', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='waterfront', data=df_test, ax=ax[1])

# %% [markdown]
# * 마찬가지로 분포가 0으로 쏠려있습니다.

# %% [markdown]
# #### 1.4 결측치

# %%
import missingno as msno
msno.matrix(df_train)

# %%
msno.matrix(df_test)

# %% [markdown]
# 다행히도 결측치는 보이지 않습니다.

# %%
import plotly as py
import plotly.graph_objs as go

py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
## 유니크 갯수 계산
train_unique=[]
columns = ['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade']

for i in columns:
    train_unique.append(len(df_train[i].unique()))
    
unique_train = pd.DataFrame()
unique_train['Columns'] = columns
unique_train['Unique_value'] = train_unique

data = [
    go.Bar(
        x = unique_train['Columns'],
        y = unique_train['Unique_value'],
        name = 'Unique value in features',
        textfont = dict(size=20),
        marker = dict(opacity=0.45)
    )
]

layout = go.Layout(
    title = 'Unique Value By Column',
    xaxis = dict(title='Columns', ticklen=5, zeroline=False, gridwidth=2),
    yaxis = dict(title='Value Count', ticklen=5, gridwidth=2),
    showlegend = True
)

fig = go.Figure(data=data, layout=layout)
# py.offline.iplot(fig, filename='skin')
py.offline.iplot(fig)
# Out:
# <div id="1c8954bc-49ea-4b39-90ea-3fdabde54682" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1c8954bc-49ea-4b39-90ea-3fdabde54682", [{"marker": {"opacity": 0.45}, "name": "Unique value in features", "textfont": {"size": 20}, "x": ["bedrooms", "bathrooms", "floors", "waterfront", "view", "condition", "grade"], "y": [11, 29, 6, 2, 5, 5, 12], "type": "bar", "uid": "78851318-a814-4faa-b654-d00d81251540"}], {"showlegend": true, "title": "Unique Value By Column", "xaxis": {"gridwidth": 2, "ticklen": 5, "title": "Columns", "zeroline": false}, "yaxis": {"gridwidth": 2, "ticklen": 5, "title": "Value Count"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){Plotly.Plots.resize(document.getElementById("1c8954bc-49ea-4b39-90ea-3fdabde54682"));});</script>

# %% [markdown]
# view의 유니크 개수가 5인걸로 보니 grade와 같이 순위형 변수로 생각되어지고, waterfront같은 경우는 2개로 있다, 없다를 뜻하는 것 같습니다.

# %% [markdown]
# ### 2. 데이터 전처리

# %% [markdown]
# #### 2.1 이상치 제거
# 위에서 중요한 변수들에 대해 다음의 변수들에 대해 이상치가 있는것을 확인할 수 있습니다.
# * sqft_living, grade, bathrooms
# <br></br>
# ##### 2.1.1 sqft_living

# %%
data = pd.concat([df_train['sqft_living'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_living', y='price', data=data)

# %%
df_train[df_train['sqft_living'] > 13000]
# Out:
#         id             date      price  bedrooms  bathrooms  sqft_living  \
# 8912  8912  20140505T000000  14.639686         7        8.0        13540
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 8912    307752     3.0           0     4     ...         12        9410
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8912           4130      1999             0    98053  47.6675 -121.986
#
#       sqft_living15  sqft_lot15
# 8912           4850      217800
#
# [1 rows x 21 columns]

# %% [markdown]
# 위의 값을 봤을때, 다른값들에 비해 sqft_living 값만 비정상적으로 큰 것을 알 수 있습니다. 따라서 이 값은 이상치로 보고 제거하도록 하겠습니다.

# %%
df_train = df_train.loc[df_train['id'] != 8912]

# %% [markdown]
# ##### 2.1.2 grade

# %%
data = pd.concat([df_train['grade'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x='grade', y='price', data=data)

# %%
df_train.loc[(df_train['price']>14.5) & (df_train['grade']==7)]
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 12346  12346  20150115T000000  14.533351         4       3.25         3580
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 12346     19989     1.5           1     4     ...          7        3480
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12346            100      1915          1965    98125  47.7087 -122.276
#
#        sqft_living15  sqft_lot15
# 12346           2410        6389
#
# [1 rows x 21 columns]

# %%
df_train.loc[(df_train['price']>14.7) & (df_train['grade']==8)]
# Out:
#         id             date      price  bedrooms  bathrooms  sqft_living  \
# 7173  7173  20140813T000000  14.808763         5        4.0         4230
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 7173     27295     2.0           1     4     ...          8        3230
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7173           1000      1949          1985    98033  47.6803 -122.214
#
#       sqft_living15  sqft_lot15
# 7173           2660       27295
#
# [1 rows x 21 columns]

# %%
df_train.loc[(df_train['price']>15.5) & (df_train['grade']==11)]
# Out:
#         id             date     price  bedrooms  bathrooms  sqft_living  \
# 2775  2775  20140611T000000  15.77031         5        4.5        10040
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 2775     37325     2.0           1     2     ...         11        7680
#
#       sqft_basement  yr_built  yr_renovated  zipcode    lat     long  \
# 2775           2360      1940          2001    98004  47.65 -122.214
#
#       sqft_living15  sqft_lot15
# 2775           3930       25449
#
# [1 rows x 21 columns]

# %% [markdown]
# 위의 3개의 값 모두 특별한 이유 없이 가격이 높아 보이므로 이상치로 규정하고 제거하도록 하겠습니다.

# %%
df_train = df_train.loc[df_train['id'] != 12346]
df_train = df_train.loc[df_train['id'] != 7173]
df_train = df_train.loc[df_train['id'] != 2775]

# %% [markdown]
# ##### 2.1.3 bedrooms

# %%
data = pd.concat([df_train['bedrooms'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x='bedrooms', y='price', data=data)

# %% [markdown]
# 침실의 수를 보면 9까지는 price가 증가하는 모습을 보이지만 10 이상부터는 그렇지 않습니다.

# %%
df_train.loc[df_train['bedrooms']>=10]
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 9280    9280  20140814T000000  13.953533        10       5.25         4590
# 10575  10575  20141029T000000  13.384729        10       2.00         3610
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 9280      10920     1.0           0     2     ...          9        2500
# 10575     11914     2.0           0     0     ...          7        3010
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9280            2090      2008             0    98004  47.5861 -122.113
# 10575            600      1958             0    98006  47.5705 -122.175
#
#        sqft_living15  sqft_lot15
# 9280            2730       10400
# 10575           2040       11914
#
# [2 rows x 21 columns]

# %%
df_test.loc[df_test['bedrooms']>=10]
# Out:
#          id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2584  17619  20140821T000000        11       3.00         3000      4960
# 4710  19745  20140625T000000        33       1.75         1620      6000
# 5775  20810  20141229T000000        10       3.00         2920      3745
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 2584     2.0           0     0          3      7        2400            600
# 4710     1.0           0     0          5      7        1040            580
# 5775     2.0           0     0          4      7        1860           1060
#
#       yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2584      1918          1999    98106  47.5560 -122.363           1420
# 4710      1947             0    98103  47.6878 -122.331           1330
# 5775      1913             0    98105  47.6635 -122.320           1810
#
#       sqft_lot15
# 2584        4960
# 4710        4700
# 5775        3745

# %% [markdown]
# #### 2.2 정규화
# * baseline의 링크를 활용해 편향된 데이터들을 정규화 해주겠습니다.[링크](https://www.kaggle.com/kcs93023/2019-ml-month-2nd-baseline)

# %%
skew_columns = ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']
skew_columns2 = ['sqft_living15', 'sqft_lot15'] # 1/3 제곱시켜 정규분포에 가깝게!

for c in skew_columns:
    df_train[c] = np.log1p(df_train[c].values)
    df_test[c] = np.log1p(df_test[c].values)
    
for c in skew_columns2:
    df_train[c] = np.power(df_train[c].values, 1/3)
    df_test[c] = np.power(df_test[c].values, 1/3)

# %% [markdown]
# #### 2.3 변수 수정

# %%
for df in [df_train, df_test]:
    df['date'] = df['date'].apply(lambda x: x[0:8])
    df['yr_renovated'] = df['yr_renovated'].apply(lambda x: np.nan if x == 0 else x)
    df['yr_renovated'] = df['yr_renovated'].fillna(df['yr_built'])

# %% [markdown]
# ### 3.변수 생성

# %%
df_train.head()
# Out:
#    id      date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013  12.309987         3       1.00     7.074117  8.639588
# 1   1  20150225  12.100718         2       1.00     6.647688  9.210440
# 2   2  20150218  13.142168         3       2.00     7.427144  8.997271
# 3   3  20140627  12.458779         3       2.25     7.447751  8.827615
# 4   4  20150115  12.583999         3       1.50     6.966967  9.181118
#
#    floors  waterfront  view     ...      grade  sqft_above  sqft_basement  \
# 0     1.0           0     0     ...          7    7.074117            0.0
# 1     1.0           0     0     ...          6    6.647688            0.0
# 2     1.0           0     0     ...          8    7.427144            0.0
# 3     2.0           0     0     ...          7    7.447751            0.0
# 4     1.0           0     0     ...          7    6.966967            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955        1955.0    98178  47.5112 -122.257      11.024738
# 1      1933        1933.0    98028  47.7379 -122.233      13.959064
# 2      1987        1987.0    98074  47.6168 -122.045      12.164404
# 3      1995        1995.0    98003  47.3097 -122.327      13.080370
# 4      1963        1963.0    98198  47.4095 -122.315      11.816658
#
#    sqft_lot15
# 0   17.810775
# 1   20.051534
# 2   19.576948
# 3   18.962994
# 4   21.334771
#
# [5 rows x 21 columns]

# %%
for df in [df_train, df_test]:
    df['total_rooms'] = df['bedrooms'] + df['bathrooms']
    # 거실의 비율
    df['sqft_ratio'] = df['sqft_living'] / df['sqft_lot']
    # 총 면적
    df['sqft_total_size'] = df['sqft_living'] + df['sqft_lot'] + df['sqft_above'] + df['sqft_basement']
    # 면적 대비 거실 비율
#     df['sqft_ratio_1'] = df['sqft_living'] / df['sqft_total_size']
    df['sqft_total15'] = df['sqft_living15'] + df['sqft_lot15']
#     df['sqft_ratio15'] = df['sqft_living15'] / df['sqft_total15'] 

    df['is_renovated'] = df['yr_renovated'] - df['yr_built']
    df['is_renovated'] = df['is_renovated'].apply(lambda x: 0 if x==0 else 1)
    df['date'] = df['date'].astype('int')

# %% [markdown]
# 아래는 집값 같은 경우에는 비슷한 지역에 영향을 받아서 그것을 코드로 구현한 것입니다. 주의해야 할 점은 단순 집값이 아니라 평당 가격을 써야한다는 점입니다.
# * 변수를 생성해 Polynomial한 특성을 추가해 준다.

# %%
df_train['per_price'] = df_train['price'] / df_train['sqft_total_size']
zipcode_price = df_train.groupby(['zipcode'])['per_price'].agg({'mean', 'var'}).reset_index()
df_train = pd.merge(df_train, zipcode_price, how='left', on='zipcode')
df_test = pd.merge(df_test, zipcode_price, how='left', on='zipcode')
del df_train['per_price']

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

train_columns = [c for c in df_train.columns if c not in ['id', 'price', 'per_price']]

# statsmodel 모듈의 OLS(Ordinary Least Squares) 클래스를 사용해 회귀분석을 한다.
# 사용법 : OLS(y,X)
model = sm.OLS(df_train['price'], df_train[train_columns])
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.000e+06
# Date:                Wed, 19 Jun 2019   Prob (F-statistic):               0.00
# Time:                        02:32:03   Log-Likelihood:                 387.27
# No. Observations:               15031   AIC:                            -728.5
# Df Residuals:                   15008   BIC:                            -553.3
# Df Model:                          23
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# date             1.672e-06   1.95e-07      8.560      0.000    1.29e-06    2.05e-06
# bedrooms           -0.0304      0.003    -11.265      0.000      -0.036      -0.025
# bathrooms           0.0411      0.003     12.123      0.000       0.034       0.048
# sqft_living        -0.1972      0.030     -6.666      0.000      -0.255      -0.139
# sqft_lot            0.1402      0.017      8.016      0.000       0.106       0.174
# floors             -0.0149      0.006     -2.382      0.017      -0.027      -0.003
# waterfront          0.3918      0.025     15.429      0.000       0.342       0.442
# view                0.0651      0.003     21.880      0.000       0.059       0.071
# condition           0.0638      0.003     19.041      0.000       0.057       0.070
# grade               0.1481      0.003     49.798      0.000       0.142       0.154
# sqft_above          0.1941      0.023      8.592      0.000       0.150       0.238
# sqft_basement      -0.0617      0.003    -23.714      0.000      -0.067      -0.057
# yr_built           -0.0018      0.000     -4.468      0.000      -0.003      -0.001
# yr_renovated       -0.0011      0.000     -2.740      0.006      -0.002      -0.000
# zipcode            -0.0005   4.48e-05    -11.693      0.000      -0.001      -0.000
# lat                 0.9327      0.019     48.755      0.000       0.895       0.970
# long                0.1440      0.023      6.370      0.000       0.100       0.188
# sqft_living15       0.0407      0.002     24.908      0.000       0.037       0.044
# sqft_lot15         -0.0209      0.001    -22.413      0.000      -0.023      -0.019
# total_rooms         0.0107      0.002      6.414      0.000       0.007       0.014
# sqft_ratio          2.3248      0.182     12.775      0.000       1.968       2.682
# sqft_total_size     0.0754      0.002     32.420      0.000       0.071       0.080
# sqft_total15        0.0198      0.001     24.329      0.000       0.018       0.021
# is_renovated        0.1444      0.024      5.970      0.000       0.097       0.192
# mean                4.1950      0.149     28.229      0.000       3.904       4.486
# var               135.5903      4.564     29.706      0.000     126.643     144.537
# ==============================================================================
# Omnibus:                      391.784   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              825.622
# Skew:                           0.150   Prob(JB):                    5.23e-180
# Kurtosis:                       4.108   Cond. No.                     1.00e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.09e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# $R^2$ 를 보면 1로 되어있어 회귀모델의 설명력은 굉장히 높지만, 각각의 변수들 중에서는 P-value가 높은 값들이 있음을 확인할 수 있습니다. 그러한 이유를 생각해 보면 Feature engineering해서 나온 파생변수들은 기존의 변수와 연관되어있고, sqft_로 시작하는 변수들 끼리의 상관성이 있어서 **다중공선성**등의 문제를 가지기 때문입니다. 실제로 다중공선성을 체크하기 위해 vif를 이용한 확인을 하면 다음과 같습니다.

# %%
vif = pd.DataFrame()
vif['Features'] = df_train.columns
vif['VIF Values'] = [variance_inflation_factor(df_train.values, i) for i in range(df_train.shape[1])]

vif.sort_values(by='VIF Values', ascending=False)
# Out:
#            Features    VIF Values
# 20       sqft_lot15           inf
# 19    sqft_living15           inf
# 3          bedrooms           inf
# 4         bathrooms           inf
# 5       sqft_living           inf
# 6          sqft_lot           inf
# 24     sqft_total15           inf
# 23  sqft_total_size           inf
# 21      total_rooms           inf
# 12       sqft_above           inf
# 13    sqft_basement           inf
# 16          zipcode  5.262126e+06
# 1              date  4.200447e+06
# 18             long  2.067173e+06
# 17              lat  2.589666e+05
# 15     yr_renovated  1.708833e+05
# 14         yr_built  1.644392e+05
# 22       sqft_ratio  6.555732e+03
# 2             price  3.068601e+03
# 26             mean  1.572637e+03
# 11            grade  1.672608e+02
# 27              var  6.338362e+01
# 10        condition  3.728245e+01
# 7            floors  2.687803e+01
# 25     is_renovated  6.614686e+00
# 0                id  4.309670e+00
# 9              view  1.562540e+00
# 8        waterfront  1.223448e+00

# %% [markdown]
# **VIF(Variance Inflation Factor)**[[출처](https://datascienceschool.net/view-notebook/36176e580d124612a376cf29872cd2f0/)]<br>
# 다중공선성을 없애는 가장 기본적인 방법은 다른 독립변수에 의존하는 변수를 없애는 것이다. 가장 의존적인 독립변수를 선택하는 방법으로는 VIF(Variance inflation factor)를 사용할 수 있다. VIF는 독립변수를 다른 독립변수로 선형회귀한 성능을 나타낸 것이이다. 다른 변수에 의존적일 수록 VIF가 커진다.|

# %% [markdown]
# 보통의 경우 10이상이면 다중공선성이 존재한다고 말하는데, 위의 식에서는 is_renovated, view, waterfront 3가지 변수를 제외한 모든 변수가 다중 공선성이 존재하는 문제점이 생겼습니다.<br><br>
# 이를 해결하기위한 방안으로는<br>
# * 다중 공선성이 robust한 트리모델을 사용하는 방법
# * 다른 독립변수에게 의존도가 높은 변수제거 및 Feature Engineering, 변환 등을 통한 대체
# * 관측값을 늘려 표본의 크기를 증가
# <br><br>
# 가 있는데, 세 번째 방안은 현재 실현이 불가능하고, 선형회귀를 사용해야하면 두 번째 방법을 사용하고, 그렇지 않을 경우에는 1번 방안을 사용하면 됩니다.

# %% [markdown]
# ### 4. 모델링

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline

# %%
y_reg = df_train['price']
del df_train['price']
del df_train['id']
test_id = df_test['id']
del df_test['id']

# %%
kfolds = KFold(n_splits=10, random_state=2019, shuffle=True)

def cv_rmse(model):
    rmse = np.sqrt(-cross_val_score(estimator=model, X=df_train, y=y_reg, scoring='neg_mean_squared_error', cv=kfolds))
    return rmse

# %% [markdown]
# #### 4.1 GBM
# ##### 4.1.1 LightGBM

# %%
train_columns = [c for c in df_train.columns if c not in ['id']]

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

param = {
    'num_leaves' : 31,
    'min_data_in_leaf' : 10,
    'objective' : 'regression',
    'max_depth' : -1,
    'learning_rate' : 0.008,
    'min_child_samples' : 12,
    'boosting' : 'gbdt',
    'feature_fraction' : 0.3,
    'bagging_freq' : 1,
    'bagging_fraction' : 0.6,
    'bagging_seed' : 11,
    'metric' : 'rmse',
    'lambda_l2' : 8,
    'verbosity' : -1,
    'nthread' : -1,
    'random_state' : 2019
}

# prepare fit model with cross-validation
folds = KFold(n_splits=5, shuffle=True, random_state=2019)
oof1 = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

# run model
for fold_, (trn_index, val_index) in enumerate(folds.split(df_train)):
    trn_data = lgb.Dataset(df_train.iloc[trn_index][train_columns], label=y_reg.iloc[trn_index])
    val_data = lgb.Dataset(df_train.iloc[val_index][train_columns], label=y_reg.iloc[val_index])
    
    num_round = 10000
    clf = lgb.train(params=param, train_set=trn_data, num_boost_round=num_round, valid_sets=[trn_data, val_data], verbose_eval=500, early_stopping_rounds=500)
    oof1[val_index] = clf.predict(df_train.iloc[val_index][train_columns], num_iterations=clf.best_iteration) # 나중에 스태킹을 위한 train 데이터도 된다.
    # feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df['Feature'] = train_columns
    fold_importance_df['importance'] = clf.feature_importance()
    
    fold_importance_df['fold'] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    # predictions
    predictions += clf.predict(df_test[train_columns], num_iterations=clf.best_iteration) / folds.n_splits # 나중에 스태킹을 위한 test 데이터도 된다.
    
cv = np.sqrt(mean_squared_error(oof1, y_reg))
print(cv)
# Out:
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse:
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 0.171685	valid_1's rmse: 0.187276
# [1000]	training's rmse: 0.146319	valid_1's rmse: 0.1687
# [1500]	training's rmse: 0.135241	valid_1's rmse: 0.164285
# [2000]	training's rmse: 0.127231	valid_1's rmse: 0.162285
# [2500]	training's rmse: 0.120757	valid_1's rmse: 0.161329
# [3000]	training's rmse: 0.115197	valid_1's rmse: 0.160794
# [3500]	training's rmse: 0.110366	valid_1's rmse: 0.160458
# [4000]	training's rmse: 0.105933	valid_1's rmse: 0.160248
# [4500]	training's rmse: 0.101914	valid_1's rmse: 0.160124
# [5000]	training's rmse: 0.0981936	valid_1's rmse: 0.159947
# [5500]	training's rmse: 0.0946801	valid_1's rmse: 0.159905
# [6000]	training's rmse: 0.0914051	valid_1's rmse: 0.159778
# [6500]	training's rmse: 0.0883338	valid_1's rmse: 0.159733
# [7000]	training's rmse: 0.0854477	valid_1's rmse: 0.159664
# [7500]	training's rmse: 0.0827286	valid_1's rmse: 0.159663
# [8000]	training's rmse: 0.0800929	valid_1's rmse: 0.159697
# Early stopping, best iteration is:
# [7571]	training's rmse: 0.0823431	valid_1's rmse: 0.159653
# 0.15643283184233517

# %%
# plot the feature importance
cols = feature_importance_df[['Feature', 'importance']].groupby('Feature').mean().sort_values(by='importance',ascending=False)[:1000].index
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x='importance', y='Feature', data=best_features.sort_values(by='importance',ascending=False))
plt.title('LightBGM Features(averaged over folds)')
plt.tight_layout()
plt.savefig('lgbm_importaces.png')

# %% [markdown]
# * 연구를 하며 발견한 점이 있는데, l2 정규화의 수치를 높여 과적합을 막으면 public score가 더욱 좋아지고,
# * l2 정규화의 수치를 낮춰 과적합을 덜 막으면 private score가 좋아지는 경향이 있었습니다.

# %% [markdown]
# ##### 4.1.2 XGBoost

# %%
import xgboost as xgb

params = {
    'booster' : 'gbtree',
    'max_depth': 7,
    'eta' : 0.008,
    'objective' : 'reg:linear',
    'eval_metric' : 'rmse',
    'n_thread' : -1,
    'silent' : 1,
    'lambda' : 8,
    'sub_sample' : 0.5,
    'random_state' : 2019
}

# prepare fit model with cross-validation
oof2 = np.zeros(len(df_train))
predictions2 = np.zeros((len(df_test)))
feature_importance_df2 = pd.DataFrame()

num_rounds = 10000
for folds_, (trn_index, val_index) in enumerate(folds.split(df_train)):
    trn_dmtx = xgb.DMatrix(data=df_train.iloc[trn_index][train_columns].values, label=y_reg.iloc[trn_index].values)
    val_dmtx = xgb.DMatrix(data=df_train.iloc[val_index][train_columns].values, label=y_reg.iloc[val_index].values)
    
    wlist = [(trn_dmtx, 'train'),(val_dmtx, 'eval')]
    clf = xgb.train(params=params, dtrain=trn_dmtx, num_boost_round=num_rounds, evals=wlist, verbose_eval=100, early_stopping_rounds=100)
    oof2[val_index] = clf.predict(data=val_dmtx) # 스태킹 모델링을 위해 남겨놓는다(스태킹 모델의 훈련 데이터)
    
    # 스테킹 모델의 테스트 데이터가 된다.
    predictions2 += clf.predict(data=xgb.DMatrix(data=df_test[train_columns].values)) / folds.n_splits
    
cv = np.sqrt(mean_squared_error(oof2, y_reg))
print(cv)
# Out:
# [0]	train-rmse:12.4588	eval-rmse:12.4571
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [1500]	train-rmse:0.125313	eval-rmse:0.15623
# [1600]	train-rmse:0.123761	eval-rmse:0.155941
# [1700]	train-rmse:0.122424	eval-rmse:0.155751
# [1800]	train-rmse:0.121048	eval-rmse:0.155511
# [1900]	train-rmse:0.119275	eval-rmse:0.155332
# [2000]	train-rmse:0.117854	eval-rmse:0.155182
# [2100]	train-rmse:0.116888	eval-rmse:0.155027
# [2200]	train-rmse:0.116565	eval-rmse:0.154991
# [2300]	train-rmse:0.116218	eval-rmse:0.154968
# [2400]	train-rmse:0.116113	eval-rmse:0.15495
# Stopping. Best iteration:
# [2372]	train-rmse:0.116115	eval-rmse:0.154949
#
# [0]	train-rmse:12.458	eval-rmse:12.4603
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:5.59701	eval-rmse:5.59878
# [200]	train-rmse:2.52612	eval-rmse:2.52779
# [300]	train-rmse:1.15614	eval-rmse:1.15864
# [400]	train-rmse:0.551767	eval-rmse:0.556783
# [500]	train-rmse:0.296	eval-rmse:0.305428
# [600]	train-rmse:0.198165	eval-rmse:0.213837
# [700]	train-rmse:0.164954	eval-rmse:0.185591
# [800]	train-rmse:0.152238	eval-rmse:0.176756
# [900]	train-rmse:0.145816	eval-rmse:0.173121
# [1000]	train-rmse:0.141136	eval-rmse:0.170875
# [1100]	train-rmse:0.136952	eval-rmse:0.169156
# [1200]	train-rmse:0.133529	eval-rmse:0.167946
# [1300]	train-rmse:0.131882	eval-rmse:0.167396
# [1400]	train-rmse:0.131122	eval-rmse:0.16717
# [1500]	train-rmse:0.130578	eval-rmse:0.167008
# [1600]	train-rmse:0.130499	eval-rmse:0.167007
# [1700]	train-rmse:0.130323	eval-rmse:0.166954
# [1800]	train-rmse:0.130177	eval-rmse:0.166912
# [1900]	train-rmse:0.130116	eval-rmse:0.166903
# Stopping. Best iteration:
# [1804]	train-rmse:0.130144	eval-rmse:0.166903
#
# 0.1612571643160134

# %% [markdown]
# * 그와 다르게 XGBoost는 과적합을 어느정도 막는것이 private score와 public score 둘 다 좋은 점수를 가져왔습니다.

# %% [markdown]
# #### 4.2 랜덤포레스트(RandomForest)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=300, random_state=2019, max_depth=15, n_jobs=-1).fit(df_train, y_reg)

# %%
print('RandomForest rmse:', cv_rmse(rf_reg).mean())
# Out:
# RandomForest rmse: 0.17559912691272933

# %%
# plot the feature importance
feature_importance_df_rf = pd.Series(data=rf_reg.feature_importances_, index=df_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(12,15), nrows=1, ncols=1)
sns.barplot(x=feature_importance_df_rf, y=feature_importance_df_rf.index, ax=ax)

# %% [markdown]
# #### 4.3 서포트벡터머신

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

svr_reg = make_pipeline(StandardScaler(), SVR(C=3.5)).fit(df_train, y_reg)

# %%
print('Support Vector Regressor rmse :', cv_rmse(svr_reg).mean())
# Out:
# Support Vector Regressor rmse : 0.18550767877730728

# %% [markdown]
# #### 4.4 ExtraTreeRegressor

# %%
from sklearn.tree import ExtraTreeRegressor

extra_tree_reg = ExtraTreeRegressor(criterion='mse', max_depth=15, min_samples_leaf=10, min_samples_split=10, max_features='auto',random_state=2019).fit(df_train, y_reg)

# %%
print('ExtraTreeRegressor rmse :', cv_rmse(extra_tree_reg).mean())
# Out:
# ExtraTreeRegressor rmse : 0.2231648066224488

# %% [markdown]
# #### 4.5 다층 퍼셉트론(Keras) [참고커널](https://www.kaggle.com/janged/keras-neural-network-0320)

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import keras.backend as K

# %%
# 먼저 모델링 전 데이터들을 퍼셉트론이 가장 잘 학습할 수 있도록 정규화 해주도록 하자.
from sklearn.preprocessing import StandardScaler

x_scaler = StandardScaler().fit(df_train)
y_scaler = StandardScaler().fit(y_reg.values.reshape(-1,1))

x_train = x_scaler.transform(df_train)
x_test = x_scaler.transform(df_test)
y_train = y_scaler.transform(y_reg.values.reshape(-1,1))

# %%
print(x_train.shape[1])
# Out:
# 26

# %%
np.random.seed(2019) # for reproduction

# %%
# root mean squared error를 평가 메트릭으로 사용하기위해 함수를 정의
def root_mean_squared_error(y_pred, y_true):
    squared_err = K.square(K.sum(y_true - y_pred, axis=0))
    mse = K.mean(squared_err)
    return K.sqrt(mse)

# %%
# 모델링
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(12, activation='relu', input_dim=x_train.shape[1], kernel_initializer='he_uniform'))
    model.add(layers.Dense(6, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dense(3, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dense(1))
    
    optimizer = optimizers.Adam(lr=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=[root_mean_squared_error])
    
    return model

# %%
# 하이퍼 파라미터 정의
epoch = 200
patient = 20
k = 5
folds = KFold(n_splits=k, shuffle=True, random_state=2019)

# %%
import os
model_path = './model'

if not os.path.exists(model_path):
    os.mkdir(model_path)
    
model_path1 = model_path + 'adam_model1.h5'

# %% [markdown]
# 훈련중 모델 결과를 저장할 디렉터리, 파일명

# %%
call_backs = [
    EarlyStopping(monitor='mse', patience=patient, mode='min', verbose=1),
    ModelCheckpoint(filepath=model_path1, monitor='mse', verbose=1, save_best_only=True, mode='min'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=patient/3, min_lr=0.000001, verbose=1, mode='min')
]

# %% [markdown]
# 에폭은 200, 각 훈련마다 patient는 20, 5폴드 1개 모델로 하고 KFold를 사용해 Fold는 섞었다.

# %%
# 스태킹 모델링을 위해
oof_percep = np.zeros(len(x_train))
prediction_percep = np.zeros(len(x_test))

# 학습
for folds_, (trn_idx, val_idx) in enumerate(folds.split(x_train)):
    print('처리중인 폴드 #', folds_)
    # 학습 데이터
    partial_train_data = x_train[trn_idx]
    partial_train_targets = y_train[trn_idx]
    
    # 검증 데이터
    val_data = x_train[val_idx]
    val_targets = y_train[val_idx]
    
    model = build_model()
    history = model.fit(partial_train_data,
                       partial_train_targets,
                       validation_data=(val_data, val_targets),
                        epochs=epoch,
                        batch_size=16,
                        callbacks=call_backs
                       )
    # 가중치 저장
    if not os.path.exists('./weight_data'):
        os.mkdir('./weight_data')
    model.save_weights('./weight_data/train_fold{}'.format(folds_))
    
    oof_percep[val_idx] = model.predict(val_data).squeeze()
    prediction_percep += model.predict(x_test).squeeze() / folds.n_splits
# Out:
# 처리중인 폴드 # 0
# Train on 12024 samples, validate on 3007 samples
# Epoch 1/200
# 12024/12024 [==============================] - 2s 148us/step - loss: 0.3844 - root_mean_squared_error: 2.1121 - val_loss: 0.2289 - val_root_mean_squared_error: 1.5233
# Epoch 2/200
# 12024/12024 [==============================] - 1s 83us/step - loss: 0.2081 - root_mean_squared_error: 1.4659 - val_loss: 0.2002 - val_root_mean_squared_error: 1.5107
# Epoch 3/200
# 12024/12024 [==============================] - 1s 80us/step - loss: 0.1862 - root_mean_squared_error: 1.4028 - val_loss: 0.1839 - val_root_mean_squared_error: 1.4169
# Epoch 4/200
# 12024/12024 [==============================] - 1s 82us/step - loss: 0.1748 - root_mean_squared_error: 1.3853 - val_loss: 0.1781 - val_root_mean_squared_error: 1.5227
# Epoch 5/200
# 12024/12024 [==============================] - 1s 82us/step - loss: 0.1668 - root_mean_squared_error: 1.3554 - val_loss: 0.1676 - val_root_mean_squared_error: 1.3268
# Epoch 6/200
# 12024/12024 [==============================] - 1s 120us/step - loss: 0.1596 - root_mean_squared_error: 1.2835 - val_loss: 0.1650 - val_root_mean_squared_error: 1.4092
# Epoch 7/200
# 12024/12024 [==============================] - 1s 108us/step - loss: 0.1541 - root_mean_squared_error: 1.2743 - val_loss: 0.1580 - val_root_mean_squared_error: 1.3239
# Epoch 8/200
# 12024/12024 [==============================] - 1s 109us/step - loss: 0.1479 - root_mean_squared_error: 1.2310 - val_loss: 0.1540 - val_root_mean_squared_error: 1.3776
# Epoch 9/200
# 12024/12024 [==============================] - 1s 104us/step - loss: 0.1431 - root_mean_squared_error: 1.2576 - val_loss: 0.1475 - val_root_mean_squared_error: 1.2739
# Epoch 10/200
# 12024/12024 [==============================] - 1s 100us/step - loss: 0.1381 - root_mean_squared_error: 1.2148 - val_loss: 0.1425 - val_root_mean_squared_error: 1.1965
# Epoch 11/200
# 12024/12024 [==============================] - 1s 102us/step - loss: 0.1346 - root_mean_squared_error: 1.1950 - val_loss: 0.1406 - val_root_mean_squared_error: 1.1956
# Epoch 12/200
# 12024/12024 [==============================] - 1s 100us/step - loss: 0.1317 - root_mean_squared_error: 1.2380 - val_loss: 0.1389 - val_root_mean_squared_error: 1.2876
# Epoch 13/200
# 12024/12024 [==============================] - 1s 103us/step - loss: 0.1283 - root_mean_squared_error: 1.1933 - val_loss: 0.1361 - val_root_mean_squared_error: 1.3424
# Epoch 14/200
# 12024/12024 [==============================] - 1s 108us/step - loss: 0.1266 - root_mean_squared_error: 1.1547 - val_loss: 0.1344 - val_root_mean_squared_error: 1.1117
# Epoch 15/200
# 12024/12024 [==============================] - 1s 103us/step - loss: 0.1253 - root_mean_squared_error: 1.1875 - val_loss: 0.1346 - val_root_mean_squared_error: 1.2239
# 12025/12025 [==============================] - 2s 177us/step - loss: 0.4399 - root_mean_squared_error: 2.0109 - val_loss: 0.2424 - val_root_mean_squared_error: 1.6806
# Epoch 2/200
# 12025/12025 [==============================] - 1s 97us/step - loss: 0.2191 - root_mean_squared_error: 1.4937 - val_loss: 0.2024 - val_root_mean_squared_error: 1.6687
# Epoch 3/200
# 12025/12025 [==============================] - 1s 107us/step - loss: 0.1946 - root_mean_squared_error: 1.4246 - val_loss: 0.1873 - val_root_mean_squared_error: 1.5045
# Epoch 4/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1828 - root_mean_squared_error: 1.3241 - val_loss: 0.1843 - val_root_mean_squared_error: 1.7903
# Epoch 5/200
# 12025/12025 [==============================] - 1s 99us/step - loss: 0.1752 - root_mean_squared_error: 1.3993 - val_loss: 0.1711 - val_root_mean_squared_error: 1.4454
# Epoch 6/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1682 - root_mean_squared_error: 1.2920 - val_loss: 0.1648 - val_root_mean_squared_error: 1.4040
# Epoch 7/200
# 12025/12025 [==============================] - 1s 102us/step - loss: 0.1613 - root_mean_squared_error: 1.3131 - val_loss: 0.1594 - val_root_mean_squared_error: 1.4424
# Epoch 8/200
# 12025/12025 [==============================] - 1s 107us/step - loss: 0.1547 - root_mean_squared_error: 1.1804 - val_loss: 0.1532 - val_root_mean_squared_error: 1.4066
# Epoch 9/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1485 - root_mean_squared_error: 1.2505 - val_loss: 0.1445 - val_root_mean_squared_error: 1.2982
# Epoch 10/200
# 12025/12025 [==============================] - 1s 125us/step - loss: 0.1419 - root_mean_squared_error: 1.1820 - val_loss: 0.1390 - val_root_mean_squared_error: 1.3157
# Epoch 11/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1362 - root_mean_squared_error: 1.1710 - val_loss: 0.1326 - val_root_mean_squared_error: 1.3269
# Epoch 12/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1315 - root_mean_squared_error: 1.1569 - val_loss: 0.1275 - val_root_mean_squared_error: 1.2571
# Epoch 13/200
# 12025/12025 [==============================] - 1s 88us/step - loss: 0.1285 - root_mean_squared_error: 1.1702 - val_loss: 0.1289 - val_root_mean_squared_error: 1.3485
# Epoch 14/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1261 - root_mean_squared_error: 1.1433 - val_loss: 0.1226 - val_root_mean_squared_error: 1.2444
# Epoch 15/200
# 12025/12025 [==============================] - 1s 86us/step - loss: 0.1238 - root_mean_squared_error: 1.1604 - val_loss: 0.1223 - val_root_mean_squared_error: 1.2574
# Epoch 16/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1225 - root_mean_squared_error: 1.1145 - val_loss: 0.1203 - val_root_mean_squared_error: 1.2421
# Epoch 17/200
# 12025/12025 [==============================] - 1s 87us/step - loss: 0.1209 - root_mean_squared_error: 1.1053 - val_loss: 0.1185 - val_root_mean_squared_error: 1.2517
# Epoch 18/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1199 - root_mean_squared_error: 1.1074 - val_loss: 0.1169 - val_root_mean_squared_error: 1.2065
# Epoch 19/200
# 12025/12025 [==============================] - 1s 86us/step - loss: 0.1184 - root_mean_squared_error: 1.1395 - val_loss: 0.1220 - val_root_mean_squared_error: 1.4727
# Epoch 20/200
# 12025/12025 [==============================] - 1s 87us/step - loss: 0.1177 - root_mean_squared_error: 1.1106 - val_loss: 0.1194 - val_root_mean_squared_error: 1.2879
# Epoch 21/200
# 12025/12025 [==============================] - 1s 87us/step - loss: 0.1168 - root_mean_squared_error: 1.0876 - val_loss: 0.1164 - val_root_mean_squared_error: 1.2254
# Epoch 22/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1154 - root_mean_squared_error: 1.1169 - val_loss: 0.1159 - val_root_mean_squared_error: 1.2549
# Epoch 23/200
# 12025/12025 [==============================] - 1s 86us/step - loss: 0.1159 - root_mean_squared_error: 1.0590 - val_loss: 0.1136 - val_root_mean_squared_error: 1.2253
# Epoch 24/200
# 12025/12025 [==============================] - 1s 85us/step - loss: 0.1153 - root_mean_squared_error: 1.1173 - val_loss: 0.1150 - val_root_mean_squared_error: 1.1951
# Epoch 25/200
# 12025/12025 [==============================] - 1s 88us/step - loss: 0.1145 - root_mean_squared_error: 1.0980 - val_loss: 0.1138 - val_root_mean_squared_error: 1.1735
# Epoch 26/200
# 12025/12025 [==============================] - 1s 88us/step - loss: 0.1137 - root_mean_squared_error: 1.0988 - val_loss: 0.1132 - val_root_mean_squared_error: 1.1820
# Epoch 27/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.1130 - root_mean_squared_error: 1.1329 - val_loss: 0.1139 - val_root_mean_squared_error: 1.2043
# Epoch 28/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.1131 - root_mean_squared_error: 1.0870 - val_loss: 0.1143 - val_root_mean_squared_error: 1.1819
# Epoch 29/200
# 12025/12025 [==============================] - 1s 88us/step - loss: 0.1127 - root_mean_squared_error: 1.0964 - val_loss: 0.1150 - val_root_mean_squared_error: 1.2830
# Epoch 30/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1125 - root_mean_squared_error: 1.1239 - val_loss: 0.1129 - val_root_mean_squared_error: 1.1655
# Epoch 31/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1121 - root_mean_squared_error: 1.1095 - val_loss: 0.1126 - val_root_mean_squared_error: 1.2160
# Epoch 32/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1118 - root_mean_squared_error: 1.0547 - val_loss: 0.1147 - val_root_mean_squared_error: 1.3468
# Epoch 33/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1116 - root_mean_squared_error: 1.0950 - val_loss: 0.1194 - val_root_mean_squared_error: 1.5534
# Epoch 34/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1118 - root_mean_squared_error: 1.1308 - val_loss: 0.1141 - val_root_mean_squared_error: 1.3846
# Epoch 35/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1110 - root_mean_squared_error: 1.1048 - val_loss: 0.1109 - val_root_mean_squared_error: 1.1590
# Epoch 36/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1102 - root_mean_squared_error: 1.0712 - val_loss: 0.1119 - val_root_mean_squared_error: 1.1728- loss: 0.1118 - root_mean_squared_error
# Epoch 37/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.1108 - root_mean_squared_error: 1.1234 - val_loss: 0.1097 - val_root_mean_squared_error: 1.1567
# Epoch 38/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1100 - root_mean_squared_error: 1.0812 - val_loss: 0.1099 - val_root_mean_squared_error: 1.1480
# Epoch 39/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1101 - root_mean_squared_error: 1.0664 - val_loss: 0.1101 - val_root_mean_squared_error: 1.1596
# Epoch 40/200
# 12025/12025 [==============================] - 1s 88us/step - loss: 0.1102 - root_mean_squared_error: 1.1062 - val_loss: 0.1128 - val_root_mean_squared_error: 1.2692
# Epoch 41/200
# 12025/12025 [==============================] - 1s 91us/step - loss: 0.1098 - root_mean_squared_error: 1.0427 - val_loss: 0.1098 - val_root_mean_squared_error: 1.2029
# Epoch 42/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1094 - root_mean_squared_error: 1.1101 - val_loss: 0.1087 - val_root_mean_squared_error: 1.1426
# Epoch 43/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1088 - root_mean_squared_error: 1.0353 - val_loss: 0.1115 - val_root_mean_squared_error: 1.1614
# Epoch 44/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1088 - root_mean_squared_error: 1.0900 - val_loss: 0.1096 - val_root_mean_squared_error: 1.1890
# Epoch 45/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1086 - root_mean_squared_error: 1.0440 - val_loss: 0.1094 - val_root_mean_squared_error: 1.1796
# Epoch 46/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1088 - root_mean_squared_error: 1.0831 - val_loss: 0.1103 - val_root_mean_squared_error: 1.1668
# Epoch 47/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1086 - root_mean_squared_error: 1.0772 - val_loss: 0.1087 - val_root_mean_squared_error: 1.1992
# Epoch 48/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1079 - root_mean_squared_error: 1.0593 - val_loss: 0.1129 - val_root_mean_squared_error: 1.4034
# Epoch 49/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1078 - root_mean_squared_error: 1.0589 - val_loss: 0.1117 - val_root_mean_squared_error: 1.1948
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 50/200
# 12025/12025 [==============================] - 1s 93us/step - loss: 0.1056 - root_mean_squared_error: 1.0291 - val_loss: 0.1099 - val_root_mean_squared_error: 1.2301
# Epoch 51/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1054 - root_mean_squared_error: 1.0139 - val_loss: 0.1072 - val_root_mean_squared_error: 1.1550
# Epoch 52/200
# 12025/12025 [==============================] - 1s 89us/step - loss: 0.1051 - root_mean_squared_error: 1.0143 - val_loss: 0.1079 - val_root_mean_squared_error: 1.1443
# Epoch 53/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1053 - root_mean_squared_error: 1.0437 - val_loss: 0.1079 - val_root_mean_squared_error: 1.1449
# Epoch 54/200
# 12025/12025 [==============================] - 1s 90us/step - loss: 0.1053 - root_mean_squared_error: 1.0637 - val_loss: 0.1073 - val_root_mean_squared_error: 1.1407
# Epoch 55/200
# 12025/12025 [==============================] - 1s 91us/step - loss: 0.1052 - root_mean_squared_error: 1.0170 - val_loss: 0.1088 - val_root_mean_squared_error: 1.1994
# Epoch 56/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.1050 - root_mean_squared_error: 1.0699 - val_loss: 0.1080 - val_root_mean_squared_error: 1.1853
# Epoch 57/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.1047 - root_mean_squared_error: 1.0339 - val_loss: 0.1089 - val_root_mean_squared_error: 1.1752 loss: 0.1029 - root_mean_squared_err
# Epoch 58/200
# 12025/12025 [==============================] - 2s 160us/step - loss: 0.1048 - root_mean_squared_error: 1.0365 - val_loss: 0.1081 - val_root_mean_squared_error: 1.1389
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 59/200
# 12025/12025 [==============================] - 2s 175us/step - loss: 0.1036 - root_mean_squared_error: 0.9755 - val_loss: 0.1080 - val_root_mean_squared_error: 1.1712
# Epoch 60/200
# ...
# Epoch 116/200
# 12025/12025 [==============================] - 1s 106us/step - loss: 0.1003 - root_mean_squared_error: 0.9770 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0365
# Epoch 117/200
# 12025/12025 [==============================] - 1s 93us/step - loss: 0.1003 - root_mean_squared_error: 0.9825 - val_loss: 0.1153 - val_root_mean_squared_error: 1.0340
# Epoch 118/200
# 12025/12025 [==============================] - 1s 100us/step - loss: 0.1003 - root_mean_squared_error: 0.9519 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0411
# Epoch 119/200
# 12025/12025 [==============================] - 1s 110us/step - loss: 0.1002 - root_mean_squared_error: 0.9807 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0479
# Epoch 120/200
# 12025/12025 [==============================] - 2s 135us/step - loss: 0.1002 - root_mean_squared_error: 0.9677 - val_loss: 0.1151 - val_root_mean_squared_error: 1.0392
# Epoch 121/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.1003 - root_mean_squared_error: 0.9639 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0374
# Epoch 122/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1002 - root_mean_squared_error: 0.9851 - val_loss: 0.1152 - val_root_mean_squared_error: 1.0397
#
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 123/200
# 12025/12025 [==============================] - 1s 106us/step - loss: 0.1000 - root_mean_squared_error: 1.0065 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0362
# Epoch 124/200
# 12025/12025 [==============================] - 1s 119us/step - loss: 0.0999 - root_mean_squared_error: 0.9728 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0484
# Epoch 125/200
# 12025/12025 [==============================] - 1s 100us/step - loss: 0.1000 - root_mean_squared_error: 0.9717 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0414
# Epoch 126/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1000 - root_mean_squared_error: 0.9740 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0366
# Epoch 127/200
# 12025/12025 [==============================] - 1s 103us/step - loss: 0.1000 - root_mean_squared_error: 0.9566 - val_loss: 0.1151 - val_root_mean_squared_error: 1.0348
# Epoch 128/200
# 12025/12025 [==============================] - 1s 99us/step - loss: 0.1000 - root_mean_squared_error: 0.9721 - val_loss: 0.1148 - val_root_mean_squared_error: 1.0407
# Epoch 129/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.1000 - root_mean_squared_error: 0.9446 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0362
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 130/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.0999 - root_mean_squared_error: 1.0028 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0369
# Epoch 131/200
# 12025/12025 [==============================] - 1s 98us/step - loss: 0.0999 - root_mean_squared_error: 0.9846 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0367
# Epoch 132/200
# 12025/12025 [==============================] - 1s 97us/step - loss: 0.0999 - root_mean_squared_error: 0.9499 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0362
# Epoch 133/200
# 12025/12025 [==============================] - 1s 116us/step - loss: 0.0999 - root_mean_squared_error: 0.9886 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0363
# Epoch 134/200
# 12025/12025 [==============================] - 1s 114us/step - loss: 0.0999 - root_mean_squared_error: 1.0000 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0354
# Epoch 135/200
# 12025/12025 [==============================] - 1s 114us/step - loss: 0.0998 - root_mean_squared_error: 0.9572 - val_loss: 0.1150 - val_root_mean_squared_error: 1.0354
# Epoch 136/200
# 12025/12025 [==============================] - 1s 117us/step - loss: 0.0998 - root_mean_squared_error: 0.9834 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0365
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 137/200
# 12025/12025 [==============================] - 1s 120us/step - loss: 0.0998 - root_mean_squared_error: 0.9740 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0360
# Epoch 138/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0998 - root_mean_squared_error: 0.9609 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0359
# Epoch 139/200
# 12025/12025 [==============================] - 1s 93us/step - loss: 0.0998 - root_mean_squared_error: 0.9725 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0357
# Epoch 140/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0998 - root_mean_squared_error: 0.9484 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0359
# Epoch 141/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0998 - root_mean_squared_error: 0.9819 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0362
# Epoch 142/200
# 12025/12025 [==============================] - 2s 127us/step - loss: 0.0998 - root_mean_squared_error: 0.9552 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 143/200
# 12025/12025 [==============================] - 1s 120us/step - loss: 0.0998 - root_mean_squared_error: 0.9698 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0357
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 144/200
# 12025/12025 [==============================] - 2s 129us/step - loss: 0.0997 - root_mean_squared_error: 0.9612 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 145/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 0.9340 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0356
# Epoch 146/200
# 12025/12025 [==============================] - 1s 104us/step - loss: 0.0997 - root_mean_squared_error: 0.9796 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 147/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 1.0214 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 148/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 0.9536 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 149/200
# 12025/12025 [==============================] - 2s 133us/step - loss: 0.0997 - root_mean_squared_error: 0.9691 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355
# Epoch 150/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 0.9683 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 151/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 0.9918 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355
# Epoch 152/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 1.0162 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355loss: 0.0995 - root_mean_squared_error: 1.02
# Epoch 153/200
# 12025/12025 [==============================] - 1s 119us/step - loss: 0.0997 - root_mean_squared_error: 0.9395 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355
# Epoch 154/200
# 12025/12025 [==============================] - 2s 129us/step - loss: 0.0997 - root_mean_squared_error: 0.9831 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0355
# Epoch 155/200
# 12025/12025 [==============================] - 1s 105us/step - loss: 0.0997 - root_mean_squared_error: 0.9876 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 156/200
# 12025/12025 [==============================] - 1s 117us/step - loss: 0.0997 - root_mean_squared_error: 0.9904 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 157/200
# 12025/12025 [==============================] - 1s 107us/step - loss: 0.0997 - root_mean_squared_error: 0.9379 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
#
# Epoch 00157: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 158/200
# 12025/12025 [==============================] - 1s 118us/step - loss: 0.0997 - root_mean_squared_error: 0.9936 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 159/200
# 12025/12025 [==============================] - 1s 123us/step - loss: 0.0997 - root_mean_squared_error: 0.9906 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 160/200
# 12025/12025 [==============================] - 1s 103us/step - loss: 0.0997 - root_mean_squared_error: 0.9650 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 161/200
# 12025/12025 [==============================] - 1s 109us/step - loss: 0.0997 - root_mean_squared_error: 0.9906 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 162/200
# 12025/12025 [==============================] - 2s 151us/step - loss: 0.0997 - root_mean_squared_error: 0.9498 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 163/200
# 12025/12025 [==============================] - 2s 143us/step - loss: 0.0997 - root_mean_squared_error: 0.9427 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 164/200
# 12025/12025 [==============================] - 2s 140us/step - loss: 0.0997 - root_mean_squared_error: 0.9747 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 165/200
# 12025/12025 [==============================] - 2s 127us/step - loss: 0.0997 - root_mean_squared_error: 0.9733 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 166/200
# 12025/12025 [==============================] - 2s 134us/step - loss: 0.0997 - root_mean_squared_error: 0.9668 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 167/200
# 12025/12025 [==============================] - 2s 139us/step - loss: 0.0997 - root_mean_squared_error: 1.0343 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 168/200
# 12025/12025 [==============================] - 1s 121us/step - loss: 0.0997 - root_mean_squared_error: 0.9754 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 169/200
# 12025/12025 [==============================] - 1s 103us/step - loss: 0.0997 - root_mean_squared_error: 0.9706 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 170/200
# 12025/12025 [==============================] - 2s 151us/step - loss: 0.0997 - root_mean_squared_error: 0.9851 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 171/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0997 - root_mean_squared_error: 0.9492 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 172/200
# 12025/12025 [==============================] - 1s 116us/step - loss: 0.0997 - root_mean_squared_error: 0.9893 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 173/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0997 - root_mean_squared_error: 0.9915 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 174/200
# 12025/12025 [==============================] - 1s 100us/step - loss: 0.0997 - root_mean_squared_error: 0.9622 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 175/200
# 12025/12025 [==============================] - 1s 104us/step - loss: 0.0997 - root_mean_squared_error: 0.9750 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 176/200
# 12025/12025 [==============================] - 1s 107us/step - loss: 0.0997 - root_mean_squared_error: 1.0019 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 177/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0997 - root_mean_squared_error: 0.9590 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 178/200
# 12025/12025 [==============================] - 1s 124us/step - loss: 0.0997 - root_mean_squared_error: 0.9523 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 179/200
# 12025/12025 [==============================] - 1s 102us/step - loss: 0.0997 - root_mean_squared_error: 1.0010 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 180/200
# 12025/12025 [==============================] - 1s 93us/step - loss: 0.0997 - root_mean_squared_error: 0.9602 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 181/200
# 12025/12025 [==============================] - 1s 93us/step - loss: 0.0997 - root_mean_squared_error: 0.9607 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 182/200
# 12025/12025 [==============================] - 1s 97us/step - loss: 0.0997 - root_mean_squared_error: 0.9924 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 183/200
# 12025/12025 [==============================] - 1s 101us/step - loss: 0.0997 - root_mean_squared_error: 0.9778 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 184/200
# 12025/12025 [==============================] - 1s 106us/step - loss: 0.0997 - root_mean_squared_error: 0.9992 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 185/200
# 12025/12025 [==============================] - 1s 112us/step - loss: 0.0997 - root_mean_squared_error: 0.9327 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 186/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.0997 - root_mean_squared_error: 0.9684 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 187/200
# 12025/12025 [==============================] - 2s 128us/step - loss: 0.0997 - root_mean_squared_error: 0.9606 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0354
# Epoch 188/200
# 12025/12025 [==============================] - 1s 97us/step - loss: 0.0997 - root_mean_squared_error: 1.0039 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 189/200
# 12025/12025 [==============================] - 1s 101us/step - loss: 0.0997 - root_mean_squared_error: 0.9707 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 190/200
# 12025/12025 [==============================] - 1s 96us/step - loss: 0.0997 - root_mean_squared_error: 0.9781 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 191/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.0997 - root_mean_squared_error: 1.0091 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 192/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.0997 - root_mean_squared_error: 0.9512 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 193/200
# 12025/12025 [==============================] - 1s 95us/step - loss: 0.0997 - root_mean_squared_error: 0.9519 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 194/200
# 12025/12025 [==============================] - 1s 97us/step - loss: 0.0997 - root_mean_squared_error: 0.9824 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 195/200
# 12025/12025 [==============================] - 1s 109us/step - loss: 0.0997 - root_mean_squared_error: 0.9303 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 196/200
# 12025/12025 [==============================] - 1s 104us/step - loss: 0.0997 - root_mean_squared_error: 0.9801 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 197/200
# 12025/12025 [==============================] - 1s 99us/step - loss: 0.0997 - root_mean_squared_error: 1.0183 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 198/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.0997 - root_mean_squared_error: 0.9694 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 199/200
# 12025/12025 [==============================] - 1s 94us/step - loss: 0.0997 - root_mean_squared_error: 0.9505 - val_loss: 0.1149 - val_root_mean_squared_error: 1.0353
# Epoch 200/200
# 12025/12025 [==============================] - 1s 104us/step - loss: 0.0997 - root_mean_squared_error: 1.0003 - val_loss: 0.1149 - val_root_mean_squared_error: 1.03530s - loss: 0.0983 - root_mean_square

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Root_mean_squared_error')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.legend(['train', 'val'], loc='best')

# %%
# 예측결과를 저장해놓는다.
# percep_model_preds = model.predict(x_test)

# %% [markdown]
# * 12->6->3 으로 총 3개의 은닉층을 구성하였습니다.
# * 12->6 으로 2개의 은닉층을 구성하면 public score는 좋아졌는데 private score의 점수가 나빠졌고, 위와같이 3개의 층을 구성하면 public score는 나빠지고 private score는 좋아지는 결과가 나왔습니다.
# * 그 이유는 더욱 연구해보아야 할 듯 합니다.
# * 가중치 초기화는 활성화 함수를 relu 함수를 썼기 때문에 he 초기화를 했습니다.
# * l2 패널티는 0.001로 주었습니다.

# %% [markdown]
# #### 4.6 스태킹(Stacking)

# %%
# 두 종류의 모델이 필요하다.
# 하나는 지금까지 학습시킨 개별적인 기본모델들이고,
# 다른 하나는 개별 기반 모델의 예측 데이터를 학습데이터로 만들어서 학습하는 최종 메타 모델이다.

# 개별 기반 모델에서 최종 메타 모델이 사용할 학습 및 테스트용 데이터를 생성하기 위한 함수
def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n):
    # KFold는 위에서 만들어진것을 쓴다.
    # 추후에 메타 모델이 학습 데이터 반환을 위한 넘파이 배열 초기화
    train_fold_pred = np.zeros((df_train.shape[0], 1))
    test_pred = np.zeros((df_test.shape[0], folds.n_splits))
    print(model.__class__.__name__, ' model 시작')
    
    for folds_, (trn_index, val_index) in enumerate(folds.split(X_train_n)):
        # 입력된 학습 데이터에서 기반 모델이 학습/예측할 폴드 데이터 세트 추출
        print('\t폴드 세트: ', folds_, ' 시작')
        trn_data = X_train_n.iloc[trn_index]
        val_data = X_train_n.iloc[val_index]
        y_trn = y_train_n.iloc[trn_index]
        
        # 폴드 세트 내부에서 다시 만들어진 학습 데이터로 기반 모델의 학습 수행
        model.fit(trn_data, y_trn)
        # 폴드 세트 내부에서 다시 만들어진 검증 데이터로 기반 모델 예측 후 데이터 저장
        train_fold_pred[val_index,:] = model.predict(val_data).reshape(-1,1)
        # 입력된 원본 테스트 데이터를 폴드 세트 내 학습된 기반 모델에서 예측 후 데이터 저장
        test_pred[:, folds_] = model.predict(X_test_n)
        
    # 폴드 세트 내에서 원본 테스트 데이터를 예측한 데이터를 평균하여 테스트 데이터로 생성
    test_pred_mean = np.mean(test_pred, axis=1)
    
    # train_fold_predsms 최종 메타 모델이 사용하는 학습 데이터, test_pred_mean은 테스트 데이터
    return train_fold_pred, test_pred_mean

# %%
# xgboost와 lightgbm은 각각 oof1,oof2 | predictions, predictions2 로 만들어져 있으니 RandomForest와 SVR, ExtraTree 모델들만 구해본다.
rf_train, rf_test = get_stacking_base_datasets(rf_reg, df_train, y_reg, df_test)
svr_train, svr_test = get_stacking_base_datasets(svr_reg, df_train, y_reg, df_test)
extra_train, extra_test = get_stacking_base_datasets(extra_tree_reg, df_train, y_reg, df_test)

# xgboost와 lightgbm의 앙상블도 준비해보자.
# 비율은 0.4*xgb + 0.6*lgb
oof3 = 0.6 * oof1 + 0.4 * oof2
predictions3 = 0.6 * predictions + 0.4 * predictions2
# Out:
# RandomForestRegressor  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작
# Pipeline  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작
# ExtraTreeRegressor  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작

# %%
oof_percep = y_scaler.inverse_transform(oof_percep)
prediction_percep = y_scaler.inverse_transform(prediction_percep)

# %%
from sklearn.linear_model import Ridge

# 개별 모델이 반환한 테스트용 데이터 세트를 스태킹 형태로 결합
## 스택모델1 : 랜덤포레스트, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
# Stack_final_X_train = np.concatenate([rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
# Stack_final_X_test = np.concatenate([rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
#                                     svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)

## 스택모델2 : 랜덤포레스트, XGB, LGB, 0.6*LGB+0.4*XGB
# Stack_final_X_train = np.concatenate([rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), oof3.reshape(-1,1)], axis=1)
# Stack_final_X_test = np.concatenate([rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis], predictions3[:,np.newaxis]], axis=1)

## 스택모델3 : 다층 퍼셉트론, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
# Stack_final_X_train = np.concatenate([oof_percep.reshape(-1,1), rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
# Stack_final_X_test = np.concatenate([prediction_percep[:,np.newaxis], rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
#                                     svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)

## 스택모델4 : 다층 퍼셉트론, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
Stack_final_X_train = np.concatenate([oof_percep.reshape(-1,1), rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
Stack_final_X_test = np.concatenate([prediction_percep[:,np.newaxis], rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
                                    svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)


# 최종 메타 모델은 릿지 모델을 적용
meta_model_ridge = Ridge(alpha=0.1)

# 개별 모델 예측값을 기반으로 새롭게 만들어진 학습/테스트 데이터로 메타 모델 예측
meta_model_ridge.fit(Stack_final_X_train, y_reg)
final = meta_model_ridge.predict(Stack_final_X_test)

# %%
# test_ridge_preds = np.expm1(ridge_model2.predict(df_test))
# test_rf_preds = np.expm1(rf_reg.predict(df_test))
# test_lgb_preds = np.expm1(predictions)
# test_xgb_preds = np.expm1(predictions2)
# rest_ensemble_preds = 0.6*test_lgb_preds + 0.4*test_xgb_preds
# percep_inv_model_preds = np.expm1(y_scaler.inverse_transform(percep_model_preds))

stack_preds = np.expm1(final)

# %%
# submission0 = pd.DataFrame({'id' : test_id, 'price' : test_ridge_preds})
# submission0.to_csv('ridge.csv', index=False)

# %%
# submission0 = pd.DataFrame({'id' : test_id, 'price' : test_lgb_preds})
# submission0.to_csv('lgb.csv', index=False)

# %%
# submission0 = pd.DataFrame({'id' : test_id, 'price' : test_xgb_preds})
# submission0.to_csv('xgb.csv', index=False)

# %%
# submission0 = pd.DataFrame({'id' : test_id, 'price' : rest_ensemble_preds})
# submission0.to_csv('ensemble.csv', index=False)

# %%
# submission0 = pd.DataFrame({'id': test_id, 'price' : test_rf_preds})
# submission0.to_csv('rf.csv', index=False)

# %%
# submission0 = pd.DataFrame({'id': test_id, 'price' : percep_inv_model_preds.squeeze()})
# submission0.to_csv('percep_keras.csv', index=False)

# %%
# 스택모델 : 다층 퍼셉트론, 랜덤포레스트, XGB, LGB, ExtraTree
submission0 = pd.DataFrame({'id': test_id, 'price' : stack_preds})
submission0.to_csv('final-submission.csv', index=False)
print('끝!')
# Out:
# 끝!
